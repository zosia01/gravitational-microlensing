# %%
import matplotlib.animation as animation
from matplotlib import style
import numpy as np

# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
style.use('fivethirtyeight')

# %%
u = np.linspace(-5, 5, 100)
Dsl      = 0.7



z_p = 0.5*(u + np.sqrt(u**2 + 4)) 
z_m = 0.5*(u - np.sqrt(u**2 + 4)) 


y_1=1
y_2=1

A_p = (u+np.sqrt(u**2+4))**2/(4*u*np.sqrt(u**2 +4))
A_m = -(u-np.sqrt(u**2+4))**2/(4*u*np.sqrt(u**2 +4))
A= np.abs(A_p)+np.abs(A_m)

# %%
def init():
    line.set_data([], [])
    line4.set_data([], [])
    return line,
def animate(i):
    line.set_data(u[i], Dsl)
    line2.set_data(z_p[i], y_1)
    line3.set_data(z_m[i],y_2)
    line4.set_data(u[:i], A[:i])
    return line, line4

# %%
fig = plt.figure(figsize=(6,12))
ax1 = fig.add_subplot(211, xlim=(-5, 5), ylim=(-5, 5))
ax2 = fig.add_subplot(212, xlim=(-5, 5), ylim=(0, 25))

line, = ax1.plot([], [], 'ro', lw=3, color = 'red')
line2, = ax1.plot([], [], 'ro', lw=3, color = 'blue')
line3, = ax1.plot([], [], 'ro', lw=3, color = 'blue')

line4, = ax2.plot([], [], color = 'black')

circle = plt.Circle((0, 0), 1, color='g', fill=False)
ax1.add_artist(circle)
star = plt.Circle((0,0),0.1, color='y' , fill=True)
ax1.add_artist(star)




line_ani = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=200, interval=20, blit=True)
# Out:
# <img src="data:image/png;base64,..." width="600">
